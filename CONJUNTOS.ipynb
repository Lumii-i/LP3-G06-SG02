# %% [markdown]
# <a href="https://colab.research.google.com/github/Lumii-i/LP3-G06-SG02/blob/main/CONJUNTOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a={1,2,30,4}
b={5,10,1}
c=set()
for x in a:
  if not x in b:
    c.add(x)
    #agrega en otro conjun C
print(c)
# Out:
# {2, 4, 30}

# %%
a={1,2,3,4}


print("a= ",a)
b={4,5,6,7}
print("b= ",b)

x=a.intersection(b)
print("inter ",x)

ds=a.symmetric_difference(b)
print(ds)
# Out:
# a=  {1, 2, 3, 4}
# b=  {4, 5, 6, 7}
# inter  {4}
# {1, 2, 3, 5, 6, 7}

# %%
A={1,2,3,4,4}
B={4,6,7}

#print(A)
A.symmetric_difference(B)
A.intersection(B)
A.update(B)
print(A)
# Out:
# {1, 2, 3, 4, 6, 7}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **CONJUNTOS**
#
# Un conjunto es una colección bien definida de objetos, que se denominan elementos o miembros del conjunto.
#
#
# Las letras mayúsculas A, B, X, Y, . . . , denotan conjuntos
#
# y
#
# las minúsculas a, b, x, y, . . . , denotan elementos de conjuntos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La pertenencia a un conjunto se denota: a ∈ S denota que a pertenece al conjunto S.
#
#
# Ej.
# A = {1, 3, 5, 7, 9}
# y
#
#  B = {x | x es un entero par, x > 0}
#
# Es decir, A consta de los elementos 1, 3, 5, 7, 9. El segundo conjunto se lee: B es el conjunto de x tal que x es un entero par y x es mayor que 0, denota el conjunto B,

# %% [markdown]
# Algunos sinónimos de “conjunto” son “clase”, “colección” y “familia”.

# %% [markdown]
# **1.	SUBCONJUNTOS**
#
# Suponga que todo elemento de un conjunto A también es un elemento de un conjunto B;
#
# * Es decir, si a ∈ A implica que a ∈ B.
#
# *Entonces se dice que A es un subconjunto de B.
#
#
# * También se dice que A está contenido en B o que B contiene a A.
#
# * Esta relación se escribe
#
#     ***A ⊆ B o B ⊇ A***
#
#
# ---
#
#
#
# Dos conjuntos son iguales si ambos tienen los mismos elementos o, equivalentemente, si cada uno está contenido en el otro.
#
# Es decir:A = B si y sólo si A ⊆ B y B ⊆ A
#
# Si A no es un subconjunto de B , porque al menos un elemento de A no pertenece a B— se escribe A ⊈ B.
#
# * Ej.
# A = {1, 3, 4, 7, 8, 9},  B = {1, 2, 3, 4, 5}, C = {1, 3}.
#
#
# * Entonces** C ⊆ A y C ⊆ B**, ya que
# 1 y 3, los elementos de C, también son miembros de A y B.
#
#
# Pero B ⊈ A, puesto que algunos elementos de B, por ejemplo, 2 y 5, no pertenecen a A.
#
#  En forma semejante, A  ⊈ B.

# %% [markdown]
# al´p
#
# ### **CONJUNTOS EN PYTHON**
#
#
# Los conjuntos son una colección (desordenada) de elementos no repetidos.
#
# Similar a los conjuntos de matemática . se pueden implementar de diversas formas:
#
# * Lista de valores (evitando duplicados).
# * diccionario (Con claves son unicas necesariamente).
#
# Python soporta un tipo primitivo denominados SET que permite conjuntos de una manera más apropiada que usando listas y diccionarios.
#
# Declaración de un cojunto En python se realiza mediante la instruccion:
#
# *   Set(secuencia)
#
# secuencia: lista, tupla,( o string pero deben ser **inmutables**)

# %%
alpha=(1,2,2,3,5)
print(type(alpha))
a=set (alpha)
print(type(a))
b={18,1,2,3,25}
c=a.symmetric_difference(b)
print(c)
#print(a[0])
# Out:
# <class 'tuple'>
# <class 'set'>
# {18, 5, 25}

# %%
a=set ([1,2,3,5])
b=set({5,6,6,7})
s=set({6,7});
print(a);
print(b)
print(s)
# Out:
# {1, 2, 3, 5}
# {5, 6, 7}
# {6, 7}

# %%
x=[5,6,7]
s= set(x)
type(s)
print(s)
# Out:
# {5, 6, 7}

# %% [markdown]
# ##                              **SET**
# Un set es una colección que no posee órden, y por tanto, tampoco números de índex. Esto quiere decir que no podemos decidir el orden en el cual aparecerán sus elementos. En Python, los sets se escriben entre llaves

# %% [markdown]
# Difference_update(): Remueve los elementos en ...
# Union(): Entrega un set que contiene la unión de ...
# Update(): Actualiza el set con la unión de éste y

# %%
list1=[1,2,3]
list2=[4,5,6]
list3=[10,11,12]

set1 =set(list2)
set2 =set(list1)

print(set1)
print(set2)
set1.update(set2)
print(set1)
print(set2)
# Out:
# {4, 5, 6}
# {1, 2, 3}
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3}

# %%
s={"apple","banana","cherry"}
print (type(s))
print(s)

for x in s:
  print(x)

print("potato" in s)
# Out:
# <class 'list'>
# ['apple', 'banana', 'cherry']
# apple
# banana
# cherry
# False

# %%
# intercambiando items

# %%
s.add("orange")
print(s)

s.update(["orange","mango","grapes"])
print(s)
# Out:
# {'apple', 'banana', 'orange', 'cherry'}
# {'grapes', 'apple', 'banana', 'mango', 'cherry', 'orange'}

# %% [markdown]
# Longitud de un conjunto

# %%
print (len(s))
# Out:
# 3

# %%
# ELIMINAR  ITEMS DEL CONJUNTO
ll ={1,2,3,4}
ll.remove(2)
print(ll)

ll.discard(3)
print(ll)

x=ll.pop()
print(ll)
print(x)
# Out:
# {1, 3, 4}
# {1, 4}
# {4}
# 1

# %%
ll ={1,2,3,4,5}
print(ll)
ll.clear()
print(ll)

# %%
del ll
print(ll)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0eec64201892> in <module>
# ----> 1 del ll
#       2 print(ll)
#
# NameError: name 'll' is not defined

# %%
a={1,2,3}
b={3,4,5}
i= a.intersection(b)
print("interseccion",i)
ii=a.intersection_update(b)
#print(ii)

ds=a.symmetric_difference(b)
print("dif simetrica:A-B",ds)
dsb=b.symmetric_difference(a)
print("dif simetrica B-A:",dsb)
# Out:
# interseccion {3}
# dif simetrica:A-B {4, 5}
# dif simetrica B-A: {4, 5}

# %% [markdown]
# otras funciones

# %% [markdown]
# Bibliografia
# *texto en cursiva*
# ![image.png](
#
# )![image.png](
#
# )
#
# https://hetpro-store.com/TUTORIALES/set-en-python-7-colecciones/#:~:text=Un%20set%20es%20una%20colecci%C3%B3n,sets%20se%20escriben%20entre%20llaves.
#
#
# https://es.acervolima.com/conjunto-de-python-actualizar/

# %% [markdown]
# x in A → devuelve True si el elemento x pertenece al conjunto A. o x in not A → devuelve True si el elemento x no pertenece al conjunto A

# %%
a ={1,2,3,5}

# %%
9  in a
# Out:
# False

# %% [markdown]
# CONTRUCTOR DE CONJUNTOS

# %%
S = set(())

# %% [markdown]
# ### **UNION **
# # A.union(B) → retorna la unión entre los conjuntos A y B. También se puede utilizar: A|B

# %%
a={1,2,3,4};
b={4,5.6};

u = a|b
print(u)

u2 = a.union(b)
print (u2)

u3 = b.union(a)
print (u3)
# Out:
# {1, 2, 3, 4, 5.6}
# {1, 2, 3, 4, 5.6}
# {1, 2, 3, 4, 5.6}

# %%
a={1,3,5,7,9,4}
b={2,4,6,8}

a.add(11)
print(a)
ca=a.copy()
print(ca)

d =|(b)
print("diferencia: ",d)
d2=b.difference(a)
print("d2 " , d2)
# Out:
# {1, 3, 4, 5, 7, 9, 11}
# {1, 3, 4, 5, 7, 9, 11}
# diferencia:  {1, 3, 5, 7, 9, 11}
# d2  {8, 2, 6}

# %% [markdown]
# INTERSECCION
#
# A.intersection(B) → retorna la intersección entre los conjuntos A y B. Equivalente A&B

# %%
i=a.intersection(b)
print(i)
# Out:
# {4}

# %% [markdown]
# relaciones en python

# %% [markdown]
# **EJERCICIOS PLANTEADOS**
#
#
# 1.-  Implementar la diferencia de conjuntos,  SIN USAR   la funcion difference
#
# 2.- implementar la diferencia simetrica sin usa symmetric_difference
#
# 3.- Implementar Union de conjunto sin usa union

# %% [markdown]
# ### **Nuevos Ejercicios Propuestos**
#
# 4.- Implementar la INTERSECCIÓN de dos conjuntos sin usar la función `intersection()` ni el operador `&`.
#
# 5.- Implementar la verificación de SUBSET (si un conjunto es subconjunto de otro) sin usar el método `issubset()`.
#
# 6.- Implementar la verificación de SUPERSET (si un conjunto es superconjunto de otro) sin usar el método `issuperset()`.

# %% [markdown]
# ### **Más Ejercicios Propuestos**
#
# 7.- Implementar la verificación de DISJOINTS (si dos conjuntos son disjuntos, es decir, no tienen elementos en común) sin usar el método `isdisjoint()`.
#
# 8.- Implementar la función de AGREGAR un elemento a un conjunto sin usar el método `add()`.
#
# 9.- Implementar la función de ELIMINAR un elemento específico de un conjunto sin usar el método `remove()` o `discard()`.
#
# 10.- Implementar la función de EXTRAER y eliminar un elemento arbitrario de un conjunto (similar a `pop()`) sin usar el método `pop()`.

# %%
c={1,2,3}
c.add(4)
print(c)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# nivel 2

# %% [markdown]
# 11.- Implementar la verificación de igualdad de conjuntos sin usar el operador ==.
#
# 12.- Implementar la verificación de desigualdad de conjuntos sin usar el operador !=.

# %% [markdown]
# nivel 3
